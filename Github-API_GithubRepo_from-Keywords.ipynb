# %% [markdown]
# <a href="https://colab.research.google.com/github/ntp3105/NTP-Notes/blob/main/Github-API_GithubRepo_from-Keywords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: use github search restAPI which will provide github repositories details based on the keyword search. top 50 and sort by most stars

import requests

search_term = "mlops"
sort = "stars"
order = "desc"

url = f"https://api.github.com/search/repositories?q={search_term}&sort={sort}&order={order}"

headers = {"Accept": "application/vnd.github.v3+json"}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    data = response.json()
    for repo in data["items"][:50]:
        print(f"Repository name: {repo['name']}")
        print(f"Stars: {repo['stargazers_count']}")
        print(f"URL: {repo['html_url']}")
        print("------------------------")
else:
    print(f"Error: {response.status_code}")
# Out:
# Repository name: Made-With-ML
# Stars: 35787
# URL: https://github.com/GokuMohandas/Made-With-ML
# ------------------------
# Repository name: airflow
# Stars: 34621
# URL: https://github.com/apache/airflow
# ------------------------
# Repository name: jina
# Stars: 20112
# URL: https://github.com/jina-ai/jina
# ------------------------
# Repository name: vllm
# Stars: 19182
# URL: https://github.com/vllm-project/vllm
# ------------------------
# Repository name: qdrant
# Stars: 18082
# URL: https://github.com/qdrant/qdrant
# ------------------------
# Repository name: label-studio
# Stars: 16638
# URL: https://github.com/HumanSignal/label-studio
# ------------------------
# Repository name: awesome-production-machine-learning
# Stars: 16140
# URL: https://github.com/EthicalML/awesome-production-machine-learning
# ------------------------
# Repository name: argo-workflows
# Stars: 14348
# URL: https://github.com/argoproj/argo-workflows
# ------------------------
# ...
